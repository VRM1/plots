# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import rc
import numpy as np
import pandas as pd

# %%
# load variables and data
figure_nam = 'my_fig.png'
lc='dataset/'
#No of topics
tops=[5,10,30,50,100,150,200]
# load data
fil=[lc+'mens_sbs.csv',lc+'mens_spl.csv',lc+'electronics_sbs.csv',lc+'electronics_spl.csv']
df1,df2,df3,df4=pd.read_csv(fil[0]),pd.read_csv(fil[1]),pd.read_csv(fil[2]),pd.read_csv(fil[3])

# %%
# load variables and data
figure_nam = 'my_fig.png'
#No of topics
tops=df1['K']
# load data
data1= [df1['LVAE'],df1['CF-LVAE'],df1['PMF'],df1['Random']]
data2= [df2['LVAE'],df2['CF-LVAE'],df2['PMF'],df2['Random']]
data3= [df3['LVAE'],df3['CF-LVAE'],df3['PMF'],df3['Random']]
data4= [df4['LVAE'],df4['CF-LVAE'],df4['PMF'],df4['Random']]

# %%
df4
# Out:
#      K    LVAE  CF-LVAE      PMF    Random
# 0   10  0.0712   0.0911  0.00320  0.000010
# 1   50  0.0581   0.0821  0.00201  0.000020
# 2  100  0.0423   0.0584  0.00091  0.000014
# 3  200  0.0215   0.0225  0.00086  0.000035
# 4  400  0.0174   0.0182  0.00052  0.000032
# 5  600  0.0081   0.0088  0.00038  0.000013
# 6  800  0.0032   0.0046  0.00031  0.000018

# %%
def dcg_new(data_x,data1,data2,data3,data4,figure_nam,x_axis,y_lim=1,n_col=2,loc=2):
    font = {'family' : 'Serif',
        'weight' : 'normal',
        'size'   : 14}
    rc('font', **font)
    fig = plt.figure(num=1,figsize=(12,8))
    lb=['LVAE', 'CF-LVAE','PMF','Random']
    x_label='K\n'
#     x_tick_label=[100,200,400,600,800]
    x_tick_label=data_x
    list_vals1=np.array(data1[0])
    list_vals2=np.array(data1[1])
    list_vals3=np.array(data1[2])
    list_vals4=np.array(data1[3])
    
    ax = fig.add_subplot(221)
    rects1 = ax.plot(data_x,list_vals1,linewidth=1, marker='o', color='#7FFF00',label=lb[0])
    rects2 = ax.plot(data_x,list_vals2,linewidth=1, marker='x', color='#FF7F50',label=lb[1])
    rects3 = ax.plot(data_x,list_vals3,linewidth=1, marker='*', color='#DC143C',label=lb[2])
    rects4 = ax.plot(data_x,list_vals4,linewidth=1, marker='s', color='#00008B',label=lb[3])

    ax.legend(loc=1,ncol=2,prop={'size':10},frameon=True )
    ax.set_xticks(x_tick_label)
#    ax.grid(linestyle='-')
    ax.set_xlim(10,800)
    ax.set_ylim(0.000001,1)
    plt.yscale('log')
    ax.set_ylabel(x_axis,fontsize=18)
    ax.set_xlabel(x_label+"(a) Men's Clothing (Substitute)" ,fontsize=18)
    
    
    list_vals1=np.array(data2[0])
    list_vals2=np.array(data2[1])
    list_vals3=np.array(data2[2])
    list_vals4=np.array(data2[3])

    
    ax = fig.add_subplot(222)
    rects1 = ax.plot(data_x,list_vals1,linewidth=1, marker='o', color='#7FFF00',label=lb[0])
    rects2 = ax.plot(data_x,list_vals2,linewidth=1, marker='x', color='#FF7F50',label=lb[1])
    rects3 = ax.plot(data_x,list_vals3,linewidth=1, marker='*', color='#DC143C',label=lb[2])
    rects4 = ax.plot(data_x,list_vals4,linewidth=1, marker='s', color='#00008B',label=lb[3])

    ax.legend(loc=1,ncol=2,prop={'size':10},frameon=True )
    ax.set_xticks(x_tick_label)
    ax.set_xlim(10,800)
    ax.set_ylim(0.000001,1)
    plt.yscale('log')
    ax.set_ylabel(x_axis,fontsize=18)
    ax.set_xlabel(x_label+"(b) Men's Clothing (Supplement)",fontsize=18)
    
    list_vals1=np.array(data3[0])
    list_vals2=np.array(data3[1])
    list_vals3=np.array(data3[2])
    list_vals4=np.array(data3[3])

    
    ax = fig.add_subplot(223)
    rects1 = ax.plot(data_x,list_vals1,linewidth=1, marker='o', color='#7FFF00',label=lb[0])
    rects2 = ax.plot(data_x,list_vals2,linewidth=1, marker='x', color='#FF7F50',label=lb[1])
    rects3 = ax.plot(data_x,list_vals3,linewidth=1, marker='*', color='#DC143C',label=lb[2])
    rects4 = ax.plot(data_x,list_vals4,linewidth=1, marker='s', color='#00008B',label=lb[3])

    ax.legend(loc=1,ncol=2,prop={'size':10},frameon=True )
    ax.set_xticks(x_tick_label)
    ax.set_xlim(10,800)
    ax.set_ylim(0.000001,1)
    plt.yscale('log')
    ax.set_ylabel(x_axis,fontsize=18)
    ax.set_xlabel(x_label+'(c) Electronics (Substitute)',fontsize=18)
    
    list_vals1=np.array(data4[0])
    list_vals2=np.array(data4[1])
    list_vals3=np.array(data4[2])
    list_vals4=np.array(data4[3])

    
    ax = fig.add_subplot(224)
    rects1 = ax.plot(data_x,list_vals1,linewidth=1, marker='o', color='#7FFF00',label=lb[0])
    rects2 = ax.plot(data_x,list_vals2,linewidth=1, marker='x', color='#FF7F50',label=lb[1])
    rects3 = ax.plot(data_x,list_vals3,linewidth=1, marker='*', color='#DC143C',label=lb[2])
    rects4 = ax.plot(data_x,list_vals4,linewidth=1, marker='s', color='#00008B',label=lb[3])

    ax.legend(loc=1,ncol=2,prop={'size':10},frameon=True )
    ax.set_xticks(x_tick_label)
    ax.set_xlim(10,800)
    ax.set_ylim(0.000001,1)
    plt.yscale('log')
    ax.set_ylabel(x_axis,fontsize=18)
    ax.set_xlabel(x_label+'(d) Electronics (Supplement)',fontsize=18)
    
    plt.subplots_adjust(bottom = 0.1,top = 0.9,wspace = 0.2,hspace = 0.4 )
#     plt.show()
    plt.tight_layout()
    plt.savefig(figure_nam,orientation='portrait',bbox_inches='tight',dpi=300)
dcg_new(tops, data1, data2, data3, data4, figure_nam, x_axis='Precision@K', y_lim=2, n_col=2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-174-242db2bec07b> in <module>()
#      94     plt.tight_layout()
#      95     plt.savefig(figure_nam,orientation='portrait',bbox_inches='tight',dpi=300)
# ---> 96 dcg_new(tops, data1, data2, data3, data4, figure_nam, x_axis='Precision@K', y_lim=2, n_col=2)
#
# <ipython-input-174-242db2bec07b> in dcg_new(data_x, data1, data2, data3, data4, figure_nam, x_axis, y_lim, n_col, loc)
#      21
#      22     ax.legend(loc=1,ncol=2,prop={'size':10},frameon=True )
# ---> 23     ax.set_xticks(x_tick_label)
#      24 #    ax.grid(linestyle='-')
#      25     ax.set_xlim(10,800)
#
# NameError: global name 'x_tick_label' is not defined

# %%
# load variables and data
figure_nam = 'my_fig.png'
#No of topics
tops=df['Topics']
# load data
data1=[[1.3166,1.3637,1.3757,1.3983,1.4094,1.4128,1.4186],[1.72,1.8037,1.8957,1.9783,2.0794,2.1228,2.156],       
            [1.6964,1.8128,1.8596,1.8759,1.9019,1.9133,1.9186],[1.9164,2.0028,2.0596,2.1359,2.2219,2.2633,2.2986],
            [1.9166,2.1637,2.0757,2.8983,2.9094,2.4128,2.4186]]
    
data2=[[1.3166,1.3637,1.3757,1.3983,1.4094,1.4128,1.4186],[1.72,1.8037,1.8957,1.9783,2.0794,2.1228,2.156],       
        [1.6964,1.8128,1.8596,1.8759,1.9019,1.9133,1.9186],[1.9164,2.0028,2.0596,2.1359,2.2219,2.2633,2.2986],
        [1.9166,2.1637,2.0757,2.8983,2.9094,2.4128,2.4186]]
data3=[[1.3166,1.3637,1.3757,1.3983,1.4094,1.4128,1.4186],[1.72,1.8037,1.8957,1.9783,2.0794,2.1228,2.156],       
        [1.6964,1.8128,1.8596,1.8759,1.9019,1.9133,1.9186],[1.9164,2.0028,2.0596,2.1359,2.2219,2.2633,2.2986],
        [1.9166,2.1637,2.0757,2.8983,2.9094,2.4128,2.4186]]
data4=[[1.3166,1.3637,1.3757,1.3983,1.4094,1.4128,1.4186],[1.72,1.8037,1.8957,1.9783,2.0794,2.1228,2.156],       
        [1.6964,1.8128,1.8596,1.8759,1.9019,1.9133,1.9186],[1.9164,2.0028,2.0596,2.1359,2.2219,2.2633,2.2986],
        [1.9166,2.1637,2.0757,2.8983,2.9094,2.4128,2.4186]]
data5=[[1.3166,1.3637,1.3757,1.3983,1.4094,1.4128,1.4186],[1.72,1.8037,1.8957,1.9783,2.0794,2.1228,2.156],       
        [1.6964,1.8128,1.8596,1.8759,1.9019,1.9133,1.9186],[1.9164,2.0028,2.0596,2.1359,2.2219,2.2633,2.2986],
        [1.9166,2.1637,2.0757,2.8983,2.9094,2.4128,2.4186]]
